# %%
# 加载画图包
# %config InlineBackend.figure_format = 'retina'

from matplotlib import pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.font_manager as font_manager
import matplotlib as mpl
import matplotlib.patches as mp
import seaborn as sns

# 设置全局字体
font_dirs = ["/public/home/mowp/test/fonts/"]
font_files = font_manager.findSystemFonts(fontpaths=font_dirs)

for font_file in font_files:
    font_manager.fontManager.addfont(font_file)
    
plt.rcParams["font.family"] = "Arial"
plt.rcParams['font.size'] = 12
plt.rcParams['svg.fonttype'] = 'none'

# setting color palette
# pal = sns.color_palette("Paired")
# sns.set_palette(pal)
# sns.palplot(pal)

# %%
import sys
sys.path.append('/public/home/mowp/workspace/termination/cbRNA_pool/script/')

# %%
# %load_ext autoreload
# %autoreload 1
# %aimport metaplot
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
all_gene = set(metaplot.single_pa_site_gene)

# %% [markdown]
# # Pol II

# %%
treatment = '/public/home/lizw/task/pore_c/fastq/20210322-chiaporec-ab/metaplot2/sorted_20210322_chiaporec_ab_porec0414_norm.bw'
#control = '/public/home/lizw/task/pore_c/exp23_merge/result2/mapping/sorted_DpnII_run01_TAIR10.read_sort.bw'
tss_cov, pas_cov, sum_cov = metaplot.get_meta_result(treatment, all_gene)
#input_tss_cov, input_pas_cov, input_sum_cov = metaplot.get_meta_result(control, all_gene)

# %%
fig, ax = plt.subplots(1, 2, figsize=(5, 3), sharey=True)

metaplot.metaplot(ax[0], tss_cov, sum_cov, target_site='TSS', ylabel='Relative Coverage')
metaplot.metaplot(ax[1], pas_cov, sum_cov, target_site='PAS', label='Pol II')

ax[1].spines['left'].set_visible(False)
ax[1].yaxis.set_ticks_position('none')

plt.setp(ax[1].get_yticklabels(), visible=False)
plt.tight_layout()
plt.legend(loc=2,bbox_to_anchor=(1.05,1.0),borderaxespad = 0.)
plt.subplots_adjust(wspace=.05)
plt.savefig('/public/home/lizw/task/pore_c/fastq/20210322-chiaporec-ab/metaplot2/metaplot.chia-porec.input_normalized.svg',format='svg',bbox_inches = 'tight')

# %%
fig, ax = plt.subplots(1, 2, figsize=(5, 3), sharey=True)

metaplot.metaplot(ax[0], input_tss_cov, input_sum_cov, target_site='TSS', ylabel='CPM Normailzed signal')
metaplot.metaplot(ax[1], input_pas_cov, input_sum_cov, target_site='PAS', label='Input')


ax[1].spines['left'].set_visible(False)
ax[1].yaxis.set_ticks_position('none')

plt.setp(ax[1].get_yticklabels(), visible=False)
plt.tight_layout()
plt.subplots_adjust(wspace=.05)
plt.savefig('/public/home/lizw/task/pore_c/exp3_chia_ab/20210322_1009_MN29338_FAP69509_936eca5a/metaplot/metaplot.input_normalized.svg',format='svg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-acfde1fb085d> in <module>
#       1 fig, ax = plt.subplots(1, 2, figsize=(5, 3), sharey=True)
#       2
# ----> 3 metaplot.metaplot(ax[0], input_tss_cov, input_sum_cov, target_site='TSS', ylabel='CPM Normailzed signal')
#       4 metaplot.metaplot(ax[1], input_pas_cov, input_sum_cov, target_site='PAS', label='Input')
#       5
#
# NameError: name 'input_tss_cov' is not defined

# %%
import pandas
