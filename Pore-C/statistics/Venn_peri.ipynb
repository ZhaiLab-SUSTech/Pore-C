# %% [markdown]
# # ab_group and3

# %%
import pandas as pd

a_comb = pd.read_csv('/public/home/lizw/task/pore_c/porec_1000_filter_mainchr_result/porecplot_v3/porec_pre_v2.2/peri_20210831/a_comb.csv',header=None,names=['read_name','comb1','comb2'])

b_comb = pd.read_csv('/public/home/lizw/task/pore_c/porec_1000_filter_mainchr_result/porecplot_v3/porec_pre_v2.2/peri_20210831/b_comb.csv',header=None,names=['read_name','comb1','comb2'])

a_comb_readID_set = set(a_comb['read_name'])

b_comb_readID_set = set(b_comb['read_name'])

import matplotlib.pyplot as plt
from matplotlib_venn import venn2, venn2_circles
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
font_dirs = ["/public/home/lizw/software/font"]
font_files = font_manager.findSystemFonts(fontpaths=font_dirs)
for font_file in font_files:
    font_manager.fontManager.addfont(font_file)
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 15
venn2([a_comb_readID_set,b_comb_readID_set],('Group a','Group b'),set_colors=('steelblue', 'darkred'),alpha=0.7)
plt.savefig('/public/home/lizw/task/pore_c/porec_1000_filter_mainchr_result/porecplot_v3/porec_pre_v2.2/peri_20210831/ab_venn.png',format='png',dpi=300,bbox_inches='tight')

# %% [markdown]
# # ab_group and2

# %%
import pandas as pd

a_comb = pd.read_csv('/public/home/lizw/task/pore_c/porec_1000_filter_mainchr_result/porecplot_v3/porec_pre_v2.2/peri_20210831/a_comb_and2.csv',header=None,names=['read_name','comb1','comb2'])
b_comb = pd.read_csv('/public/home/lizw/task/pore_c/porec_1000_filter_mainchr_result/porecplot_v3/porec_pre_v2.2/peri_20210831/b_comb_and2.csv',header=None,names=['read_name','comb1','comb2'])
not_same_comb = pd.read_csv('/public/home/lizw/task/pore_c/porec_1000_filter_mainchr_result/porecplot_v3/porec_pre_v2.2/peri_20210831/notsamechr_crossgroup.comb.and2.csv',header=None,names=['read_name','comb1','comb2'])

a_comb_readID_set = set(a_comb['read_name'])
b_comb_readID_set = set(b_comb['read_name'])
not_same_comb_readID_set = set(not_same_comb['read_name'])

import matplotlib.pyplot as plt
from matplotlib_venn import venn2, venn2_circles, venn3, venn3_circles
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
font_dirs = ["/public/home/lizw/software/font"]
font_files = font_manager.findSystemFonts(fontpaths=font_dirs)
for font_file in font_files:
    font_manager.fontManager.addfont(font_file)
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 15
venn2([a_comb_readID_set,b_comb_readID_set],('Group a','Group b'),set_colors=('steelblue', 'darkred'),alpha=0.7)
plt.savefig('/public/home/lizw/task/pore_c/porec_1000_filter_mainchr_result/porecplot_v3/porec_pre_v2.2/peri_20210831/ab_venn.and2.png',format='png',dpi=300,bbox_inches='tight')

# %%
venn3([a_comb_readID_set,b_comb_readID_set,not_same_comb_readID_set],('Group a','Group b','Same chrom'),set_colors=('steelblue', 'darkred','lightyellow'),alpha=0.7)
plt.savefig('/public/home/lizw/task/pore_c/porec_1000_filter_mainchr_result/porecplot_v3/porec_pre_v2.2/peri_20210831/ab_venn3.and2.png',format='png',dpi=300,bbox_inches='tight')

# %%
venn3_circles([a_comb_readID_set,b_comb_readID_set,not_same_comb_readID_set],('Group a','Group b','Same chrom'),set_colors=('steelblue', 'darkred','lightyellow'),alpha=0.7)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-11-6e14e1f02fb2> in <module>
# ----> 1 venn3_circles([a_comb_readID_set,b_comb_readID_set,not_same_comb_readID_set],('Group a','Group b','Same chrom'),set_colors=('steelblue', 'darkred','lightyellow'),alpha=0.7)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib_venn/_venn3.py in venn3_circles(subsets, normalize_to, alpha, color, linestyle, linewidth, ax, **kwargs)
#     283         subsets = compute_venn3_subsets(*subsets)
#     284
# --> 285     areas = compute_venn3_areas(subsets, normalize_to)
#     286     centers, radii = solve_venn3_circles(areas)
#     287
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib_venn/_venn3.py in compute_venn3_areas(diagram_areas, normalize_to, _minimal_area)
#      48         return (1e-06, 1e-06, 1e-06, 0.0, 0.0, 0.0, 0.0)
#      49     else:
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn2, venn2_circles, venn3, venn3_circles
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
font_dirs = ["/public/home/lizw/software/font"]
font_files = font_manager.findSystemFonts(fontpaths=font_dirs)
for font_file in font_files:
    font_manager.fontManager.addfont(font_file)
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 18
from matplotlib import pyplot as plt
import numpy as np
from matplotlib_venn import venn3, venn3_circles
 
# Make a Basic Venn
v = venn3(subsets=[a_comb_readID_set,b_comb_readID_set,not_same_comb_readID_set], set_labels = ('Group a','Group b',' '),set_colors=('steelblue', 'darkred','lightyellow'),alpha=0.7)
 
# Add title and annotation
plt.annotate('Same chrom', xy=v.get_label_by_id('C').get_position() - np.array([0, -0.15]), xytext=(-70,-70),
ha='center', textcoords='offset points',
arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=0.5',color='gray'))
 
# Show it
plt.savefig('/public/home/lizw/task/pore_c/porec_1000_filter_mainchr_result/porecplot_v3/porec_pre_v2.2/peri_20210831/ab_venn3.and2.png',format='png',dpi=300,bbox_inches='tight')
